# %%
import matplotlib.pyplot as plt
import numpy as np
import numerical_function_spaces.orlicz_spaces as osm

# %%
def Orlicz_function(u):
    return np.where(u <=1, 0, u - 1)

# %%
p_plus = osm.right_side_derivative(Orlicz_function, u_max=100, du=0.01)

# %%
Psi = osm.conjugate_function(Orlicz_function, u_max=100, du=0.01)
# Out:
# b_Psi = 1.01 ?
# trying to extend domain of Phi to check b_Psi - it may take a lot of time - press CTRL+C to exit (may not work) or interrupt cell
# 1-rd  extending of the Phi domain to check b_Psi
# u_max =  1010.0
# Counting Phi for extended domain
# YES: b_Psi = 1.01

# %%
osm.plot_Phi_p_plus_Psi(Orlicz_function, u_max=10, du=0.01, max_u_on_plots=10)
# Out:
# b_Psi = 1.01 ?
# trying to extend domain of Phi to check b_Psi - it may take a lot of time - press CTRL+C to exit (may not work) or interrupt cell
# 1-rd  extending of the Phi domain to check b_Psi
# u_max =  1010.0
# Counting Phi for extended domain
# YES: b_Psi = 1.01

# %%
def Orlicz_function(u):
    return np.where(u <=1, u, 2 * u - 1)

# %%
x = np.array([[1],[3]])

# %%
osm.p_Amemiya_norm_with_stars(Orlicz_function, x=x, p_norm=20,k_min=0.4, k_max=1.1,dk=0.0001,show_progress=True)
# Out:
# counting of  $\kappa_{p=20,x}(k)$ in [0.4,1.1]: 100%|██████████| 7000/7000 [00:00<00:00, 15356.12it/s]
# (np.float64(3.0000000000430203),
#  np.float64(0.645599999999973),
#  np.float64(0.9999999999999339))

# %%
import decimal as dc
dc.getcontext().prec = 50
osm.p_Amemiya_norm_with_stars_by_decimal(Orlicz_function, x=x, p_norm=dc.Decimal(10),
                                         k_min=dc.Decimal(99)/100,
                                         k_max=dc.Decimal(101)/100,
                                         dk=dc.Decimal('0.0001'),
                                         show_progress=True)
# Out:
# counting of  $\kappa_{p=10,x}(k)$ in [0.99,1.01]: 100%|██████████| 200/200 [00:00<00:00, 3199.78it/s]
# (Decimal('3.0000050804876253224732233778977489155742356587800'),
#  Decimal('1.0000'),
#  Decimal('1.0000'))
